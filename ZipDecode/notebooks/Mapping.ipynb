# %%
import pandas as pd
import geocoder
import json
import time
from flatten_json import flatten
from geocodio.client import GeocodioClient
from pandas.io.json import json_normalize
from pathlib import Path

pd.set_option('display.max_colwidth', -1)

client = GeocodioClient('{API Key}')

# %%
"""
Variables to set
"""
# Name of source file (csv file) containing latitude and longitude columns
source_filename = 'AllData.csv'

# Name of the output file (csv file)
output_filename = 'AllData_output.csv'

# %%
base_path = Path('../data/')
report_path = Path('../reports/')
source_path = base_path / ('source/')
interim_path = base_path / ('interim/')
processed_path = base_path / ('processed/')

def get_latlong(df):
    """Take a dataframe with Latitude and Longitude columns
    and extract the fields into a tupled list.

    Arguments:
        df {dataframe} -- A dataframe of the source file that contains
        Latitude and Longitude columns.

    Returns:
        list -- tupled list of Latitude Longitude.
    """
    latlong_list = list(df[['Latitude', 'Longitude']].itertuples(index=False, name=None))
    return latlong_list

def get_geoinfo(latlong_list):
    """Pass the lat long list to Geocodio to decode and then save file.

    Arguments:
        latlong_list {list} -- returned list from get_latlong()

    Returns:
        address_name -- The name of the file that was saved.
    """
    addresses = client.reverse(latlong_list)

    address_name = 'addresses_'+ time.strftime("%Y%m%d-%H%M%S") + '.json'
    address_path = interim_path / address_name

    try:
        with open(address_path, 'w') as outfile:
            json.dump(addresses, outfile)
    except:
        print('Error outputting file.')
    else:
        return address_name

def flat_zips(df_addresses):
    """Take the multi-level json results loaded into a dataframe from Geocodio and
    flattened to a list of dictionary values.  Retreive only the first result
    from each lat/long list, as each list can have multiple.  The top result is
    the most accurate.

    Arguments:
        df_addresses {dataframe} -- Take a dataframe of the Geocodio information.

    Returns:
        list -- list of dictionary geocodio results
    """
    address_list = []
    for index, row in df_addresses.iterrows():
        dic = row['results']
        dic_flattened = [flatten(d) for d in dic]
        address_list.append(dic_flattened[0])
    return address_list

def flatzips_to_df(listofzips):
    """Convert list of dictionary Geocodio results to a dataframe and rename
    column names.

    Arguments:
        listofzips {list} -- returned list from flat_zips()

    Returns:
        dataframe -- clean Geocodio dataframe results.
    """
    df = pd.DataFrame(listofzips)

    # Rename columns
    # If they have a '_' character, return right most string, else return original column header
    df.columns = [c[c.rfind('_')+1:] if '_' in c else c for c in df.columns]
    return df

def create_report(source, zips, filename):
    """Combine the original file with the Geocodio results and save to output file
    location.

    Arguments:
        source {dataframe} -- dataframe of source data
        zips {dataframe} -- returned dataframe from flatzips_to_df()
        filename {str} -- name of the output file

    Returns:
        dataframe -- dataframe of combined results.
    """
    df = pd.concat([source, zips], axis=1, sort=False)
    df.to_csv(report_path / filename)
    return df

# %%
# Create DataFrame from source file
df_source = pd.read_csv(source_path / source_filename)

# Run list of lat longs through Geocodio API and save them to a file
# Retrieve filename
geofile_name = get_geoinfo(get_latlong(df_source))
geofile_path = interim_path / geofile_name

# Open file and import into a dataframe
df_geo = pd.read_json(geofile_path)

# Flatten json structure and return the most accurate record per lat/long
df_zips = flatzips_to_df(flat_zips(df_geo))

# Move interim file to processed
geofile_path.replace(processed_path / geofile_name)

# 2467  Atlantic Beach      US      Duval County         Mayport Rd
# 2468  Ponte Vedra Beach   US      St. Johns County     I 95
# 2469  Saint Augustine     US      St. Johns County     Sr 16
# 2470  Saint Augustine     US      St. Johns County     Us Hwy 1 N
# 2471  Saint Augustine     US      St. Johns County     Charles St
# 2472  Saint Augustine     US      St. Johns County     US 1
# 2473  Saint Augustine     US      St. Johns County     US 1
# 2474  Saint Augustine     US      St. Johns County     Us Hwy 1 S
# 2475  Saint Augustine     US      St. Johns County     US 1
# 2476  Saint Augustine     US      St. Johns County     Us Hwy 1 S
# 2477  Saint Augustine     US      St. Johns County     US 1
# 2478  Saint Augustine     US      St. Johns County     US 1
# 2479  Saint Augustine     US      St. Johns County     Us Hwy 1 S
# 2480  Saint Augustine     US      St. Johns County     US 1
# 2481  Saint Augustine     US      St. Johns County     Us Hwy 1
#
#         number postdirectional predirectional state        street suffix  \
# 0     125       NaN             NaN            PA    Washington    Ln
# 1     352       NaN             NaN            PA    Pennsylvania  Ave
# 2     449       NaN             NaN            PA    Pennsylvania  Ave
# 3     507       NaN             NaN            PA    Pennsylvania  Ave
# 4     11        NaN             S              PA    21st          St
# 5     663       NaN             NaN            NJ    Mantua        Pike
# 6     555       NaN             NaN            NJ    Mantua        Pike
# 7     487       NaN             NaN            NJ    Mantua        Pike
# 8     439       NaN             NaN            NJ    Mantua        Pike
# 9     3701      NaN             NaN            PA    Farm School   Rd
# 10    2519R-21  NaN             N              PA    Broad         St
# 11    613       NaN             NaN            NJ    Glassboro     Rd
# 12    1653      NaN             NaN            PA    Belfield      Ave
# 13    53        NaN             S              PA    Keswick       Ave
# 14    731       NaN             N              NJ    Broad         St
# 15    549       NaN             N              PA    Easton        Rd
# 16    7360      NaN             NaN            PA    Easton        Rd
# 17    5825      NaN             N              PA    Broad         St
# 18    NaN       NaN             NaN            PA    I 95          NaN
# 19    1022      NaN             N              NJ    Evergreen     Ave
# 20    3670      NaN             NaN            PA    Sawmill       Rd
# 21    NaN       NaN             NaN            PA    PA 611        NaN
# 22    407       NaN             NaN            PA    Baeder        Rd
# 23    4459      NaN             W              PA    Swamp         Rd
# 24    1000      NaN             NaN            NJ    Gateway       Blvd
# 25    120       NaN             NaN            PA    Swamp         Rd
# 26    876       NaN             N              PA    Easton        Rd
# 27    1607      NaN             NaN            PA    Easton        Rd
# 28    4311      NaN             NaN            PA    Swamp         Rd
# 29    854       NaN             N              PA    Easton        Rd
# ...   ...       ...            ..              ..       ...        ..
# 2452  10920     NaN             NaN            FL    Atlantic      Blvd
# 2453  10980     NaN             NaN            FL    Atlantic      Blvd
# 2454  10979     NaN             NaN            FL    Atlantic      Blvd
# 2455  11003     NaN             NaN            FL    Atlantic      Blvd
# 2456  NaN       NaN             NaN            FL    I 295         NaN
# 2457  11107     NaN             NaN            FL    Atlantic      Blvd
# 2458  11211     NaN             NaN            FL    Atlantic      Blvd
# 2459  11225     NaN             NaN            FL    Atlantic      Blvd
# 2460  11335     NaN             NaN            FL    Atlantic      Blvd
# 2461  11401     NaN             NaN            FL    Atlantic      Blvd
# 2462  2266      S               NaN            FL    8th           St
# 2463  2194      NaN             NaN            FL    Sadler        Rd
# 2464  14133     NaN             NaN            FL    Us Hwy 90     NaN
# 2465  660       NaN             NaN            FL    Mayport       Rd
# 2466  NaN       NaN             NaN            FL    I 95          NaN
# 2467  2126      NaN             NaN            FL    Mayport       Rd
# 2468  NaN       NaN             NaN            FL    I 95          NaN
# 2469  1900      NaN             NaN            FL    Sr 16         NaN
# 2470  4662      N               NaN            FL    Us Hwy 1      NaN
# 2471  10        NaN             NaN            FL    Charles       St
# 2472  NaN       NaN             NaN            FL    US 1          NaN
# 2473  NaN       NaN             NaN            FL    US 1          NaN
# 2474  2950      S               NaN            FL    Us Hwy 1      NaN
# 2475  NaN       NaN             NaN            FL    US 1          NaN
# 2476  2657      S               NaN            FL    Us Hwy 1      NaN
# 2477  NaN       NaN             NaN            FL    US 1          NaN
# 2478  NaN       NaN             NaN            FL    US 1          NaN
# 2479  2275      S               NaN            FL    Us Hwy 1      NaN
# 2480  NaN       NaN             NaN            FL    US 1          NaN
# 2481  1663      NaN             NaN            FL    Us Hwy 1      NaN
#
#         zip                                          address        lat  \
# 0     19034  125 Washington Ln, Fort Washington, PA 19034     40.139083
# 1     19034  352 Pennsylvania Ave, Fort Washington, PA 19034  40.137473
# 2     19034  449 Pennsylvania Ave, Fort Washington, PA 19034  40.134989
# 3     19034  507 Pennsylvania Ave, Fort Washington, PA 19034  40.134554
# 4     19103  11 S 21st St, Philadelphia, PA 19103             39.953071
# 5     08096  663 Mantua Pike, Woodbury, NJ 08096              39.825612
# 6     08096  555 Mantua Pike, Woodbury, NJ 08096              39.828058
# 7     08096  487 Mantua Pike, Woodbury, NJ 08096              39.830720
# 8     08096  439 Mantua Pike, Woodbury, NJ 08096              39.831954
# 9     18942  3701 Farm School Rd, Ottsville, PA 18942         40.458395
# 10    19132  2519R-21 N Broad St, Philadelphia, PA 19132      39.991248
# 11    08097  613 Glassboro Rd, Woodbury Heights, NJ 08097     39.825821
# 12    19141  1653 Belfield Ave, Philadelphia, PA 19141        40.028037
# 13    19038  53 S Keswick Ave, Glenside, PA 19038             40.099616
# 14    08096  731 N Broad St, Woodbury, NJ 08096               39.847072
# 15    19038  549 N Easton Rd, Glenside, PA 19038              40.110248
# 16    18947  7360 Easton Rd, Pipersville, PA 18947            40.439146
# 17    19141  5825 N Broad St, Philadelphia, PA 19141          40.042178
# 18    19123  I 95, Philadelphia, PA 19123                     39.959731
# 19    08096  1022 N Evergreen Ave, Woodbury, NJ 08096         39.849667
# 20    18902  3670 Sawmill Rd, Doylestown, PA 18902            40.335269
# 21    19044  PA 611, Horsham, PA 19044                        40.199917
# 22    19046  407 Baeder Rd, Jenkintown, PA 19046              40.101313
# 23    18901  4459 W Swamp Rd, Doylestown, PA 18901            40.333363
# 24    08093  1000 Gateway Blvd, Westville, NJ 08093           39.862727
# 18   -75.140867
# 19   -75.141843
# 20   -75.138062
# 21   -75.138938
# 22   -75.138072
# 23   -75.136199
# 24   -75.135099
# 25   -75.134233
# 26   -75.132757
# 27   -75.131355
# 28   -75.131606
# 29   -75.132007
# ...         ...
# 2452 -81.518215
# 2453 -81.515984
# 2454 -81.514948
# 2455 -81.513109
# 2456 -81.513857
# 2457 -81.511213
# 2458 -81.509409
# 2459 -81.507301
# 2460 -81.505768
# 2461 -81.504084
# 2462 -81.458328
# 2463 -81.445119
# 2464 -81.445413
# 2465 -81.418072
# 2466 -81.415672
# 2467 -81.413922
# 2468 -81.413613
# 2469 -81.394093
# 2470 -81.339496
# 2471 -81.334172
# 2472 -81.322967
# 2473 -81.322314
# 2474 -81.322424
# 2475 -81.322467
# 2476 -81.322614
# 2477 -81.322395
# 2478 -81.322580
# 2479 -81.322839
# 2480 -81.322525
# 2481 -81.321576
#
#                                                                                             source
# 0     TIGER/Line® dataset from the US Census Bureau
# 1     TIGER/Line® dataset from the US Census Bureau
# 2     TIGER/Line® dataset from the US Census Bureau
# 3     TIGER/Line® dataset from the US Census Bureau
# 4     Philadelphia
# 5     NJ Office of Information Technology (NJOIT), Office of Geographic Information Systems (OGIS)
# 6     NJ Office of Information Technology (NJOIT), Office of Geographic Information Systems (OGIS)
# 7     NJ Office of Information Technology (NJOIT), Office of Geographic Information Systems (OGIS)
# 8     NJ Office of Information Technology (NJOIT), Office of Geographic Information Systems (OGIS)
# 9     Bucks
# 10    Philadelphia
# 11    NJ Office of Information Technology (NJOIT), Office of Geographic Information Systems (OGIS)
# 12    Philadelphia
# 13    TIGER/Line® dataset from the US Census Bureau
# 14    NJ Office of Information Technology (NJOIT), Office of Geographic Information Systems (OGIS)
# 15    TIGER/Line® dataset from the US Census Bureau
# 16    TIGER/Line® dataset from the US Census Bureau
# 17    Philadelphia
# 18    TIGER/Line® dataset from the US Census Bureau
# 19    NJ Office of Information Technology (NJOIT), Office of Geographic Information Systems (OGIS)
# 20    Bucks
# 21    TIGER/Line® dataset from the US Census Bureau
# 22    TIGER/Line® dataset from the US Census Bureau
# 23    Bucks
# 24    NJ Office of Information Technology (NJOIT), Office of Geographic Information Systems (OGIS)
# 25    Bucks
# 26    Bucks
# 27    Bucks
# 28    Bucks
# 29    Bucks
# ...     ...
# 2452  MapWise (and individual Florida counties)
# 2453  MapWise (and individual Florida counties)
# 2454  MapWise (and individual Florida counties)
# 2455  MapWise (and individual Florida counties)
# 2456  TIGER/Line® dataset from the US Census Bureau
# 2457  Duval
# 2458  Duval
# 2459  MapWise (and individual Florida counties)
# 2460  MapWise (and individual Florida counties)
# 2461  Duval
# 2462  MapWise (and individual Florida counties)
# 2463  Nassau
# 2464  TIGER/Line® dataset from the US Census Bureau
# 2465  Duval
# 2466  TIGER/Line® dataset from the US Census Bureau
# 2467  Duval
# 2468  TIGER/Line® dataset from the US Census Bureau
# 2469  St Johns
# 2470  TIGER/Line® dataset from the US Census Bureau
# 2471  Loveland
# 2472  TIGER/Line® dataset from the US Census Bureau
# 2473  TIGER/Line® dataset from the US Census Bureau
# 2474  TIGER/Line® dataset from the US Census Bureau
# 2475  TIGER/Line® dataset from the US Census Bureau
# 2476  TIGER/Line® dataset from the US Census Bureau
# 2477  TIGER/Line® dataset from the US Census Bureau
# 2478  TIGER/Line® dataset from the US Census Bureau
# 2479  TIGER/Line® dataset from the US Census Bureau
# 2480  TIGER/Line® dataset from the US Census Bureau
# 2481  TIGER/Line® dataset from the US Census Bureau
#
# [2482 rows x 20 columns]
